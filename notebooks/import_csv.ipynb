# %%
import pandas as pd
# Out:
# Running cells with 'weather_study (3.13.5) (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/hinz1/Documents/weather_study/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
